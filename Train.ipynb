# %%
# !pip install tensorboard

# %%
import torch
import os
import sys
from models.autoencoder import AutoEncoder
import time
from datetime import datetime
import torch.optim as optim
from torch.utils.tensorboard import SummaryWriter
from models.utils import  AverageMeter, str2bool
from dataset.dataset import CompressDataset
from args.shapenet_args import parse_shapenet_args
from args.semantickitti_args import parse_semantickitti_args
from torch.optim.lr_scheduler import StepLR
from models.Chamfer3D.dist_chamfer_3D import chamfer_3DDist
chamfer_dist = chamfer_3DDist()
# Out:
# Loaded compiled 3D CUDA chamfer distance

# %%
def train(args):
    start = time.time()

    if args.batch_size > 1:
        print('The performance will degrade if batch_size is larger than 1!')

    if args.compress_normal == True:
        args.in_fdim = 6

    # load data
    train_dataset = CompressDataset(data_path=args.train_data_path, cube_size=args.train_cube_size, batch_size=args.batch_size)
    train_loader = torch.utils.data.DataLoader(dataset=train_dataset, shuffle=True, batch_size=args.batch_size)

    val_dataset = CompressDataset(data_path=args.val_data_path, cube_size=args.val_cube_size, batch_size=args.batch_size)
    val_loader = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=args.batch_size)

    # set up folders for checkpoints
    str_time = datetime.now().isoformat()
    print('Experiment Time:', str_time)
    checkpoint_dir = os.path.join(args.output_path, str_time, 'ckpt')
    if not os.path.exists(checkpoint_dir):
        os.makedirs(checkpoint_dir)

    # create the model
    model = AutoEncoder(args)
    model = model.cuda()
    print('Training Arguments:', args)
    print('Model Architecture:', model)

    # optimizer for autoencoder
    parameters = set(p for n, p in model.named_parameters() if not n.endswith(".quantiles"))
    optimizer = optim.Adam(parameters, lr=args.lr)
    # lr scheduler
    scheduler_steplr = StepLR(optimizer, step_size=args.lr_decay_step, gamma=args.gamma)
    # optimizer for entropy bottleneck
    aux_parameters = set(p for n, p in model.named_parameters() if n.endswith(".quantiles"))
    aux_optimizer = optim.Adam(aux_parameters, lr=args.aux_lr)

    # best validation metric
    best_val_chamfer_loss = float('inf')

   # train
    for epoch in range(args.epochs):
        epoch_loss = AverageMeter()
        epoch_chamfer_loss = AverageMeter()
        epoch_density_loss = AverageMeter()
        epoch_pts_num_loss = AverageMeter()
        epoch_latent_xyzs_loss = AverageMeter()
        epoch_normal_loss = AverageMeter()
        epoch_bpp_loss = AverageMeter()
        epoch_aux_loss = AverageMeter()
        
        model.train()

        for i, input_dict in enumerate(train_loader):
            # input: (b, n, c)
            input = input_dict['xyzs'].cuda()
            # input: (b, c, n)
            input = input.permute(0, 2, 1).contiguous()

            # compress normal
            if args.compress_normal == True:
                normals = input_dict['normals'].cuda().permute(0, 2, 1).contiguous()
                input = torch.cat((input, normals), dim=1)

            # model forward
            decompressed_xyzs, loss, loss_items, bpp = model(input)
            epoch_loss.update(loss.item())
            epoch_chamfer_loss.update(loss_items['chamfer_loss'])
            epoch_density_loss.update(loss_items['density_loss'])
            epoch_pts_num_loss.update(loss_items['pts_num_loss'])
            epoch_latent_xyzs_loss.update(loss_items['latent_xyzs_loss'])
            epoch_normal_loss.update(loss_items['normal_loss'])
            epoch_bpp_loss.update(loss_items['bpp_loss'])

            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # update the parameters of entropy bottleneck
            aux_loss = model.feats_eblock.loss()
            if args.quantize_latent_xyzs == True:
                aux_loss += model.xyzs_eblock.loss()
            epoch_aux_loss.update(aux_loss.item())

            aux_optimizer.zero_grad()
            aux_loss.backward()
            aux_optimizer.step()

            # print loss
            if (i+1) % args.print_freq == 0:
                print("train epoch: %d/%d, iters: %d/%d, loss: %f, avg chamfer loss: %f, "
                      "avg density loss: %f, avg pts num loss: %f, avg latent xyzs loss: %f, "
                      "avg normal loss: %f, avg bpp loss: %f, avg aux loss: %f" %
                      (epoch+1, args.epochs, i+1, len(train_loader), epoch_loss.get_avg(), epoch_chamfer_loss.get_avg(),
                       epoch_density_loss.get_avg(), epoch_pts_num_loss.get_avg(), epoch_latent_xyzs_loss.get_avg(),
                       epoch_normal_loss.get_avg(), epoch_bpp_loss.get_avg(), epoch_aux_loss.get_avg()))

        scheduler_steplr.step()

        # print loss
        interval = time.time() - start
        print("train epoch: %d/%d, time: %d mins %.1f secs, loss: %f, avg chamfer loss: %f, "
              "avg density loss: %f, avg pts num loss: %f, avg latent xyzs loss: %f, "
              "avg normal loss: %f, avg bpp loss: %f, avg aux loss: %f" %
              (epoch+1, args.epochs, interval/60, interval%60, epoch_loss.get_avg(), epoch_chamfer_loss.get_avg(),
               epoch_density_loss.get_avg(), epoch_pts_num_loss.get_avg(), epoch_latent_xyzs_loss.get_avg(),
               epoch_normal_loss.get_avg(), epoch_bpp_loss.get_avg(), epoch_aux_loss.get_avg()))


        # validation
        model.eval()
        val_chamfer_loss = AverageMeter()
        val_normal_loss = AverageMeter()
        val_bpp = AverageMeter()
        with torch.no_grad():
            for input_dict in val_loader:
                # xyzs: (b, n, c)
                input = input_dict['xyzs'].cuda()
                # (b, c, n)
                input = input.permute(0, 2, 1).contiguous()

                # compress normal
                if args.compress_normal == True:
                    normals = input_dict['normals'].cuda().permute(0, 2, 1).contiguous()
                    input = torch.cat((input, normals), dim=1)
                    args.in_fdim = 6

                # gt_xyzs
                gt_xyzs = input[:, :3, :].contiguous()

                # model forward
                decompressed_xyzs, loss, loss_items, bpp = model(input)
                # calculate val loss and bpp
                d1, d2, _, _ = chamfer_dist(gt_xyzs.permute(0, 2, 1).contiguous(),
                                            decompressed_xyzs.permute(0, 2, 1).contiguous())
                chamfer_loss = d1.mean() + d2.mean()
                val_chamfer_loss.update(chamfer_loss.item())
                val_normal_loss.update(loss_items['normal_loss'])
                val_bpp.update(bpp.item())

        # print loss
        print("val epoch: %d/%d, val bpp: %f, val chamfer loss: %f, val normal loss: %f" %
              (epoch+1, args.epochs, val_bpp.get_avg(), val_chamfer_loss.get_avg(), val_normal_loss.get_avg()))

        # save checkpoint
        cur_val_chamfer_loss = val_chamfer_loss.get_avg()
        if  cur_val_chamfer_loss < best_val_chamfer_loss or (epoch+1) % args.save_freq == 0:
            model_name = 'ckpt-best.pth' if cur_val_chamfer_loss < best_val_chamfer_loss else 'ckpt-epoch-%02d.pth' % (epoch+1)
            model_path = os.path.join(checkpoint_dir, model_name)
            torch.save(model.state_dict(), model_path)
            # update best val chamfer loss
            if cur_val_chamfer_loss < best_val_chamfer_loss:
                best_val_chamfer_loss = cur_val_chamfer_loss

def reset_model_args(train_args, model_args):
    for arg in vars(train_args):
        setattr(model_args, arg, getattr(train_args, arg))

# %%
class Arguments:
    def __init__(self):
        self.dataset = 'shapenet'
        self.lr = 0.001
        self.aux_lr = 0.001
        self.weight_decay = 0.001
        self.betas = (0.9, 0.999)
        self.lr_decay_step = 20
        self.gamma = 0.5
        self.train_data_path = './data/shapenet/shapenet_train_cube_size_22.pkl'
        self.train_cube_size = 22
        self.val_data_path = './data/shapenet/shapenet_val_cube_size_22.pkl'
        self.val_cube_size = 22
        self.test_data_path = './data/shapenet/shapenet_test_cube_size_22.pkl'
        self.test_cube_size = 22
        self.peak = 30
        self.epochs = 100
        self.batch_size = 32
        self.print_freq = 10
        self.save_freq = 5
        self.output_path = './output'
        self.compress_normal = False
        self.in_fdim = 3
        self.k = 32
        self.downsample_rate = [1/2, 1/2, 1/2]
        self.max_upsample_num = [4, 4, 4]
        self.layer_num = 3
        self.dim = 64
        self.hidden_dim = 64
        self.ngroups = 8
        self.quantize_latent_xyzs = True
        self.latent_xyzs_conv_mode = 'mlp'
        self.sub_point_conv_mode = 'mlp'
        self.chamfer_coe = 1.0
        self.pts_num_coe = 1.0
        self.normal_coe = 1.0
        self.bpp_lambda = 1e-3
        self.mean_distance_coe = 1.0
        self.density_coe = 1.0
        self.latent_xyzs_coe = 1.0
        self.model_path = './output/model.pth'
        self.density_radius = 0.05
        self.dist_coe = 1.0
        self.omega_xyzs = 1.0
        self.omega_normals = 1.0

train_args = Arguments()

# %%
train(train_args)
# Out:
# The performance will degrade if batch_size is larger than 1!
# Experiment Time: 2023-08-09T10:40:49.171484
# Training Arguments: <__main__.Arguments object at 0x7f93a5f34650>
# Model Architecture: AutoEncoder(
#   (pre_conv): Sequential(
#     (0): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU()
#     (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#   )
#   (encoder): Encoder(
#     (encoder_layers): ModuleList(
#       (0): DownsampleLayer(
#         (pre_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (feats_agg_nn): PointTransformerLayer(
#           (w_qs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_ks): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_vs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (conv_delta): Sequential(
#             (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_gamma): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (post_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         )
#         (position_embedding_nn): PositionEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (attn_nn): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (density_embedding_nn): DensityEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv1d(1, 64, kernel_size=(1,), stride=(1,))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (post_conv): Conv1d(192, 64, kernel_size=(1,), stride=(1,))
#       )
#       (1): DownsampleLayer(
#         (pre_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (feats_agg_nn): PointTransformerLayer(
#           (w_qs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_ks): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_vs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (conv_delta): Sequential(
#             (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_gamma): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (post_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         )
#         (position_embedding_nn): PositionEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (attn_nn): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (density_embedding_nn): DensityEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv1d(1, 64, kernel_size=(1,), stride=(1,))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (post_conv): Conv1d(192, 64, kernel_size=(1,), stride=(1,))
#       )
#       (2): DownsampleLayer(
#         (pre_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         (feats_agg_nn): PointTransformerLayer(
#           (w_qs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_ks): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (w_vs): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           (conv_delta): Sequential(
#             (0): Conv2d(3, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (conv_gamma): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (post_conv): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#         )
#         (position_embedding_nn): PositionEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (attn_nn): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (density_embedding_nn): DensityEmbeddingLayer(
#           (pre_nn): Sequential(
#             (0): Conv1d(1, 64, kernel_size=(1,), stride=(1,))
#             (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#             (2): ReLU(inplace=True)
#             (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#           )
#         )
#         (post_conv): Conv1d(192, 64, kernel_size=(1,), stride=(1,))
#       )
#     )
#   )
#   (feats_eblock): EntropyBottleneck(
#     (likelihood_lower_bound): LowerBound()
#   )
#   (decoder): Decoder(
#     (decoder_layers): ModuleList(
#       (0): ModuleList(
#         (0): UpsampleLayer(
#           (xyzs_upsample_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_upsample_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#         (1): UpsampleNumLayer(
#           (upsample_num_nn): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             (1): ReLU()
#             (2): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
#             (3): Sigmoid()
#           )
#         )
#         (2): RefineLayer(
#           (xyzs_refine_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_refine_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#       )
#       (1): ModuleList(
#         (0): UpsampleLayer(
#           (xyzs_upsample_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_upsample_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#         (1): UpsampleNumLayer(
#           (upsample_num_nn): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             (1): ReLU()
#             (2): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
#             (3): Sigmoid()
#           )
#         )
#         (2): RefineLayer(
#           (xyzs_refine_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_refine_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#       )
#       (2): ModuleList(
#         (0): UpsampleLayer(
#           (xyzs_upsample_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_upsample_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(16, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#         (1): UpsampleNumLayer(
#           (upsample_num_nn): Sequential(
#             (0): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#             (1): ReLU()
#             (2): Conv1d(64, 1, kernel_size=(1,), stride=(1,))
#             (3): Sigmoid()
#           )
#         )
#         (2): RefineLayer(
#           (xyzs_refine_nn): XyzsUpsampleLayer(
#             (weight_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 43, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#             (scale_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 1, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#           (feats_refine_nn): FeatsUpsampleLayer(
#             (feats_nn): SubPointConv(
#               (mlp): Sequential(
#                 (0): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#                 (1): ReLU(inplace=True)
#                 (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#               )
#             )
#           )
#         )
#       )
#     )
#   )
#   (latent_xyzs_analysis): Sequential(
#     (0): Conv1d(3, 64, kernel_size=(1,), stride=(1,))
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#     (3): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#   )
#   (xyzs_eblock): EntropyBottleneck(
#     (likelihood_lower_bound): LowerBound()
#   )
#   (latent_xyzs_synthesis): Sequential(
#     (0): Conv1d(64, 64, kernel_size=(1,), stride=(1,))
#     (1): GroupNorm(8, 64, eps=1e-05, affine=True)
#     (2): ReLU(inplace=True)
#     (3): Conv1d(64, 3, kernel_size=(1,), stride=(1,))
#   )
# )
# train epoch: 1/100, iters: 10/74, loss: 5136.781091, avg chamfer loss: 1.441436, avg density loss: 2.943222, avg pts num loss: 5131.988086, avg latent xyzs loss: 0.322662, avg normal loss: 0.000000, avg bpp loss: 0.085723, avg aux loss: 5266.370361
# train epoch: 1/100, iters: 20/74, loss: 3026.126743, avg chamfer loss: 0.899613, avg density loss: 2.824748, avg pts num loss: 3022.108472, avg latent xyzs loss: 0.209206, avg normal loss: 0.000000, avg bpp loss: 0.084722, avg aux loss: 5254.202881
# train epoch: 1/100, iters: 30/74, loss: 2370.359628, avg chamfer loss: 0.676249, avg density loss: 2.760642, avg pts num loss: 2366.681299, avg latent xyzs loss: 0.157721, avg normal loss: 0.000000, avg bpp loss: 0.083728, avg aux loss: 5241.859391
# train epoch: 1/100, iters: 40/74, loss: 2036.527983, avg chamfer loss: 0.551485, avg density loss: 2.716634, avg pts num loss: 2033.048035, avg latent xyzs loss: 0.129103, avg normal loss: 0.000000, avg bpp loss: 0.082739, avg aux loss: 5229.233093
# train epoch: 1/100, iters: 50/74, loss: 1753.909977, avg chamfer loss: 0.472573, avg density loss: 2.684765, avg pts num loss: 1750.560488, avg latent xyzs loss: 0.110402, avg normal loss: 0.000000, avg bpp loss: 0.081757, avg aux loss: 5216.274893
# train epoch: 1/100, iters: 60/74, loss: 1513.388102, avg chamfer loss: 0.416433, avg density loss: 2.658110, avg pts num loss: 1510.136141, avg latent xyzs loss: 0.096644, avg normal loss: 0.000000, avg bpp loss: 0.080781, avg aux loss: 5202.938167
# train epoch: 1/100, iters: 70/74, loss: 1335.618183, avg chamfer loss: 0.375113, avg density loss: 2.639608, avg pts num loss: 1332.437207, avg latent xyzs loss: 0.086449, avg normal loss: 0.000000, avg bpp loss: 0.079812, avg aux loss: 5189.226904
# train epoch: 1/100, time: 0 mins 39.1 secs, loss: 1280.167741, avg chamfer loss: 0.361629, avg density loss: 2.632550, avg pts num loss: 1277.011099, avg latent xyzs loss: 0.083044, avg normal loss: 0.000000, avg bpp loss: 0.079427, avg aux loss: 5183.643139
# val epoch: 1/100, val bpp: 72.213297, val chamfer loss: 0.044465, val normal loss: 0.000000
# train epoch: 2/100, iters: 10/74, loss: 508.904575, avg chamfer loss: 0.113760, avg density loss: 2.492838, avg pts num loss: 506.205273, avg latent xyzs loss: 0.021328, avg normal loss: 0.000000, avg bpp loss: 0.071371, avg aux loss: 5064.466602
# train epoch: 2/100, iters: 20/74, loss: 426.650913, avg chamfer loss: 0.110110, avg density loss: 2.500740, avg pts num loss: 423.949243, avg latent xyzs loss: 0.020373, avg normal loss: 0.000000, avg bpp loss: 0.070445, avg aux loss: 5048.653540
# train epoch: 2/100, iters: 30/74, loss: 522.807097, avg chamfer loss: 0.107175, avg density loss: 2.504194, avg pts num loss: 520.106624, avg latent xyzs loss: 0.019580, avg normal loss: 0.000000, avg bpp loss: 0.069525, avg aux loss: 5032.443148
# train epoch: 2/100, iters: 40/74, loss: 583.240941, avg chamfer loss: 0.105698, avg density loss: 2.502391, avg pts num loss: 580.545483, avg latent xyzs loss: 0.018752, avg normal loss: 0.000000, avg bpp loss: 0.068614, avg aux loss: 5015.882605
# train epoch: 2/100, iters: 50/74, loss: 636.642313, avg chamfer loss: 0.103427, avg density loss: 2.502662, avg pts num loss: 633.950420, avg latent xyzs loss: 0.018098, avg normal loss: 0.000000, avg bpp loss: 0.067708, avg aux loss: 4998.961318
# train epoch: 2/100, iters: 60/74, loss: 667.092355, avg chamfer loss: 0.101571, avg density loss: 2.504141, avg pts num loss: 664.402352, avg latent xyzs loss: 0.017480, avg normal loss: 0.000000, avg bpp loss: 0.066810, avg aux loss: 4981.685628
# train epoch: 2/100, iters: 70/74, loss: 706.494097, avg chamfer loss: 0.100355, avg density loss: 2.503738, avg pts num loss: 703.807108, avg latent xyzs loss: 0.016974, avg normal loss: 0.000000, avg bpp loss: 0.065919, avg aux loss: 4964.060728
# train epoch: 2/100, time: 1 mins 14.7 secs, loss: 718.291122, avg chamfer loss: 0.099423, avg density loss: 2.505214, avg pts num loss: 715.604103, avg latent xyzs loss: 0.016815, avg normal loss: 0.000000, avg bpp loss: 0.065564, avg aux loss: 4956.914663
# val epoch: 2/100, val bpp: 58.926812, val chamfer loss: 0.033345, val normal loss: 0.000000
# train epoch: 3/100, iters: 10/74, loss: 646.765277, avg chamfer loss: 0.086640, avg density loss: 2.466218, avg pts num loss: 644.141406, avg latent xyzs loss: 0.012840, avg normal loss: 0.000000, avg bpp loss: 0.058171, avg aux loss: 4805.064014
# train epoch: 3/100, iters: 20/74, loss: 524.196715, avg chamfer loss: 0.086592, avg density loss: 2.481019, avg pts num loss: 521.559277, avg latent xyzs loss: 0.012499, avg normal loss: 0.000000, avg bpp loss: 0.057326, avg aux loss: 4785.464478
# train epoch: 3/100, iters: 30/74, loss: 499.174151, avg chamfer loss: 0.084628, avg density loss: 2.483252, avg pts num loss: 496.537614, avg latent xyzs loss: 0.012164, avg normal loss: 0.000000, avg bpp loss: 0.056491, avg aux loss: 4765.272917
# train epoch: 3/100, iters: 40/74, loss: 513.771843, avg chamfer loss: 0.083043, avg density loss: 2.483787, avg pts num loss: 511.137488, avg latent xyzs loss: 0.011860, avg normal loss: 0.000000, avg bpp loss: 0.055664, avg aux loss: 4744.595459
# train epoch: 3/100, iters: 50/74, loss: 481.104113, avg chamfer loss: 0.081380, avg density loss: 2.482774, avg pts num loss: 478.473584, avg latent xyzs loss: 0.011530, avg normal loss: 0.000000, avg bpp loss: 0.054845, avg aux loss: 4723.411436
# train epoch: 3/100, iters: 60/74, loss: 443.451414, avg chamfer loss: 0.080099, avg density loss: 2.482257, avg pts num loss: 440.823730, avg latent xyzs loss: 0.011291, avg normal loss: 0.000000, avg bpp loss: 0.054036, avg aux loss: 4701.833162
# train epoch: 3/100, iters: 70/74, loss: 410.045760, avg chamfer loss: 0.079056, avg density loss: 2.482438, avg pts num loss: 407.420006, avg latent xyzs loss: 0.011024, avg normal loss: 0.000000, avg bpp loss: 0.053237, avg aux loss: 4679.827365
# train epoch: 3/100, time: 1 mins 50.1 secs, loss: 402.966582, avg chamfer loss: 0.078564, avg density loss: 2.482559, avg pts num loss: 400.341606, avg latent xyzs loss: 0.010932, avg normal loss: 0.000000, avg bpp loss: 0.052920, avg aux loss: 4670.913482
# val epoch: 3/100, val bpp: 46.972148, val chamfer loss: 0.022391, val normal loss: 0.000000
# train epoch: 4/100, iters: 10/74, loss: 341.861664, avg chamfer loss: 0.070023, avg density loss: 2.475903, avg pts num loss: 339.260449, avg latent xyzs loss: 0.008957, avg normal loss: 0.000000, avg bpp loss: 0.046324, avg aux loss: 4480.962451
# train epoch: 4/100, iters: 20/74, loss: 353.443354, avg chamfer loss: 0.069068, avg density loss: 2.481724, avg pts num loss: 350.838135, avg latent xyzs loss: 0.008833, avg normal loss: 0.000000, avg bpp loss: 0.045590, avg aux loss: 4456.143506
# train epoch: 4/100, iters: 30/74, loss: 319.710450, avg chamfer loss: 0.068627, avg density loss: 2.485614, avg pts num loss: 317.102637, avg latent xyzs loss: 0.008702, avg normal loss: 0.000000, avg bpp loss: 0.044867, avg aux loss: 4430.839307
# train epoch: 4/100, iters: 40/74, loss: 303.709677, avg chamfer loss: 0.067709, avg density loss: 2.482228, avg pts num loss: 301.107080, avg latent xyzs loss: 0.008503, avg normal loss: 0.000000, avg bpp loss: 0.044154, avg aux loss: 4405.137317
# train epoch: 4/100, iters: 50/74, loss: 291.576499, avg chamfer loss: 0.067585, avg density loss: 2.480504, avg pts num loss: 288.976543, avg latent xyzs loss: 0.008408, avg normal loss: 0.000000, avg bpp loss: 0.043456, avg aux loss: 4378.995166
# train epoch: 4/100, iters: 60/74, loss: 286.310951, avg chamfer loss: 0.067429, avg density loss: 2.475841, avg pts num loss: 283.716642, avg latent xyzs loss: 0.008263, avg normal loss: 0.000000, avg bpp loss: 0.042772, avg aux loss: 4352.319336
# train epoch: 4/100, iters: 70/74, loss: 285.168409, avg chamfer loss: 0.066875, avg density loss: 2.473796, avg pts num loss: 282.577525, avg latent xyzs loss: 0.008109, avg normal loss: 0.000000, avg bpp loss: 0.042101, avg aux loss: 4325.385324
# train epoch: 4/100, time: 2 mins 25.6 secs, loss: 287.719880, avg chamfer loss: 0.066657, avg density loss: 2.474641, avg pts num loss: 285.128698, avg latent xyzs loss: 0.008045, avg normal loss: 0.000000, avg bpp loss: 0.041836, avg aux loss: 4314.525813
# val epoch: 4/100, val bpp: 36.835809, val chamfer loss: 0.019095, val normal loss: 0.000000
# train epoch: 5/100, iters: 10/74, loss: 690.870079, avg chamfer loss: 0.062968, avg density loss: 2.485033, avg pts num loss: 688.278516, avg latent xyzs loss: 0.007170, avg normal loss: 0.000000, avg bpp loss: 0.036378, avg aux loss: 4083.534253
# train epoch: 5/100, iters: 20/74, loss: 609.540441, avg chamfer loss: 0.063168, avg density loss: 2.476295, avg pts num loss: 606.958057, avg latent xyzs loss: 0.007109, avg normal loss: 0.000000, avg bpp loss: 0.035808, avg aux loss: 4054.125085
# train epoch: 5/100, iters: 30/74, loss: 567.445575, avg chamfer loss: 0.062293, avg density loss: 2.475100, avg pts num loss: 564.865967, avg latent xyzs loss: 0.006960, avg normal loss: 0.000000, avg bpp loss: 0.035249, avg aux loss: 4024.806657
# train epoch: 5/100, iters: 40/74, loss: 556.319863, avg chamfer loss: 0.061503, avg density loss: 2.474427, avg pts num loss: 553.742419, avg latent xyzs loss: 0.006803, avg normal loss: 0.000000, avg bpp loss: 0.034706, avg aux loss: 3995.138239
# train epoch: 5/100, iters: 50/74, loss: 520.580795, avg chamfer loss: 0.060791, avg density loss: 2.473942, avg pts num loss: 518.005176, avg latent xyzs loss: 0.006699, avg normal loss: 0.000000, avg bpp loss: 0.034183, avg aux loss: 3964.995576
# train epoch: 5/100, iters: 60/74, loss: 505.940268, avg chamfer loss: 0.060090, avg density loss: 2.472025, avg pts num loss: 503.367912, avg latent xyzs loss: 0.006563, avg normal loss: 0.000000, avg bpp loss: 0.033674, avg aux loss: 3934.591361
# train epoch: 5/100, iters: 70/74, loss: 509.775606, avg chamfer loss: 0.059662, avg density loss: 2.472382, avg pts num loss: 507.203934, avg latent xyzs loss: 0.006441, avg normal loss: 0.000000, avg bpp loss: 0.033182, avg aux loss: 3904.077801
# train epoch: 5/100, time: 3 mins 1.1 secs, loss: 500.180604, avg chamfer loss: 0.059610, avg density loss: 2.473481, avg pts num loss: 497.608113, avg latent xyzs loss: 0.006399, avg normal loss: 0.000000, avg bpp loss: 0.032995, avg aux loss: 3891.759013
# val epoch: 5/100, val bpp: 29.249472, val chamfer loss: 0.017847, val normal loss: 0.000000
# train epoch: 6/100, iters: 10/74, loss: 499.871451, avg chamfer loss: 0.055677, avg density loss: 2.464475, avg pts num loss: 497.316504, avg latent xyzs loss: 0.005683, avg normal loss: 0.000000, avg bpp loss: 0.029119, avg aux loss: 3633.165967
# train epoch: 6/100, iters: 20/74, loss: 425.447221, avg chamfer loss: 0.056284, avg density loss: 2.472069, avg pts num loss: 422.884521, avg latent xyzs loss: 0.005627, avg normal loss: 0.000000, avg bpp loss: 0.028723, avg aux loss: 3601.814526
# train epoch: 6/100, iters: 30/74, loss: 458.347878, avg chamfer loss: 0.055908, avg density loss: 2.471029, avg pts num loss: 455.787061, avg latent xyzs loss: 0.005527, avg normal loss: 0.000000, avg bpp loss: 0.028362, avg aux loss: 3570.091292
# train epoch: 6/100, iters: 40/74, loss: 445.442751, avg chamfer loss: 0.055607, avg density loss: 2.472883, avg pts num loss: 442.880811, avg latent xyzs loss: 0.005453, avg normal loss: 0.000000, avg bpp loss: 0.028007, avg aux loss: 3538.936108
# train epoch: 6/100, iters: 50/74, loss: 405.597284, avg chamfer loss: 0.055114, avg density loss: 2.470790, avg pts num loss: 403.038340, avg latent xyzs loss: 0.005371, avg normal loss: 0.000000, avg bpp loss: 0.027676, avg aux loss: 3507.717891
# train epoch: 6/100, iters: 60/74, loss: 371.092581, avg chamfer loss: 0.054355, avg density loss: 2.469928, avg pts num loss: 368.535645, avg latent xyzs loss: 0.005300, avg normal loss: 0.000000, avg bpp loss: 0.027360, avg aux loss: 3476.718302
# train epoch: 6/100, iters: 70/74, loss: 339.536416, avg chamfer loss: 0.054081, avg density loss: 2.468998, avg pts num loss: 336.981034, avg latent xyzs loss: 0.005244, avg normal loss: 0.000000, avg bpp loss: 0.027065, avg aux loss: 3445.743572
# train epoch: 6/100, time: 3 mins 36.6 secs, loss: 336.115244, avg chamfer loss: 0.053936, avg density loss: 2.466976, avg pts num loss: 333.562170, avg latent xyzs loss: 0.005217, avg normal loss: 0.000000, avg bpp loss: 0.026950, avg aux loss: 3433.340372
# val epoch: 6/100, val bpp: 24.338961, val chamfer loss: 0.015981, val normal loss: 0.000000
# train epoch: 7/100, iters: 10/74, loss: 263.608955, avg chamfer loss: 0.051000, avg density loss: 2.472563, avg pts num loss: 261.055859, avg latent xyzs loss: 0.004878, avg normal loss: 0.000000, avg bpp loss: 0.024657, avg aux loss: 3174.220898
# train epoch: 7/100, iters: 20/74, loss: 300.578193, avg chamfer loss: 0.050539, avg density loss: 2.474152, avg pts num loss: 298.024365, avg latent xyzs loss: 0.004682, avg normal loss: 0.000000, avg bpp loss: 0.024456, avg aux loss: 3143.616382
# train epoch: 7/100, iters: 30/74, loss: 281.012103, avg chamfer loss: 0.050414, avg density loss: 2.477694, avg pts num loss: 278.455094, avg latent xyzs loss: 0.004639, avg normal loss: 0.000000, avg bpp loss: 0.024260, avg aux loss: 3114.166960
# train epoch: 7/100, iters: 40/74, loss: 250.306521, avg chamfer loss: 0.049938, avg density loss: 2.475268, avg pts num loss: 247.752661, avg latent xyzs loss: 0.004567, avg normal loss: 0.000000, avg bpp loss: 0.024089, avg aux loss: 3084.306903
# train epoch: 7/100, iters: 50/74, loss: 252.385925, avg chamfer loss: 0.049626, avg density loss: 2.473333, avg pts num loss: 249.834521, avg latent xyzs loss: 0.004526, avg normal loss: 0.000000, avg bpp loss: 0.023917, avg aux loss: 3054.977280
# train epoch: 7/100, iters: 60/74, loss: 254.384084, avg chamfer loss: 0.049458, avg density loss: 2.470380, avg pts num loss: 251.836019, avg latent xyzs loss: 0.004464, avg normal loss: 0.000000, avg bpp loss: 0.023763, avg aux loss: 3026.392196
# train epoch: 7/100, iters: 70/74, loss: 259.397402, avg chamfer loss: 0.049431, avg density loss: 2.469445, avg pts num loss: 256.850509, avg latent xyzs loss: 0.004404, avg normal loss: 0.000000, avg bpp loss: 0.023613, avg aux loss: 2997.781759
# train epoch: 7/100, time: 4 mins 12.0 secs, loss: 252.201416, avg chamfer loss: 0.049297, avg density loss: 2.469696, avg pts num loss: 249.654510, avg latent xyzs loss: 0.004366, avg normal loss: 0.000000, avg bpp loss: 0.023548, avg aux loss: 2986.602117
# val epoch: 7/100, val bpp: 21.859236, val chamfer loss: 0.013828, val normal loss: 0.000000
# train epoch: 8/100, iters: 10/74, loss: 216.072948, avg chamfer loss: 0.046864, avg density loss: 2.463771, avg pts num loss: 213.535791, avg latent xyzs loss: 0.004097, avg normal loss: 0.000000, avg bpp loss: 0.022418, avg aux loss: 2752.844727
# train epoch: 8/100, iters: 20/74, loss: 248.529923, avg chamfer loss: 0.046893, avg density loss: 2.462040, avg pts num loss: 245.994678, avg latent xyzs loss: 0.003964, avg normal loss: 0.000000, avg bpp loss: 0.022352, avg aux loss: 2725.685449
# train epoch: 8/100, iters: 30/74, loss: 261.062009, avg chamfer loss: 0.046667, avg density loss: 2.464388, avg pts num loss: 258.524740, avg latent xyzs loss: 0.003934, avg normal loss: 0.000000, avg bpp loss: 0.022283, avg aux loss: 2699.692049
# train epoch: 8/100, iters: 40/74, loss: 265.418024, avg chamfer loss: 0.046478, avg density loss: 2.464594, avg pts num loss: 262.880884, avg latent xyzs loss: 0.003886, avg normal loss: 0.000000, avg bpp loss: 0.022184, avg aux loss: 2674.960815
# train epoch: 8/100, iters: 50/74, loss: 260.429864, avg chamfer loss: 0.046197, avg density loss: 2.461070, avg pts num loss: 257.896631, avg latent xyzs loss: 0.003845, avg normal loss: 0.000000, avg bpp loss: 0.022123, avg aux loss: 2650.657446
# train epoch: 8/100, iters: 60/74, loss: 253.857028, avg chamfer loss: 0.046221, avg density loss: 2.463396, avg pts num loss: 251.321549, avg latent xyzs loss: 0.003807, avg normal loss: 0.000000, avg bpp loss: 0.022056, avg aux loss: 2626.494824
# train epoch: 8/100, iters: 70/74, loss: 254.869361, avg chamfer loss: 0.046050, avg density loss: 2.463135, avg pts num loss: 252.334403, avg latent xyzs loss: 0.003773, avg normal loss: 0.000000, avg bpp loss: 0.022001, avg aux loss: 2602.909099
# train epoch: 8/100, time: 4 mins 46.4 secs, loss: 261.090310, avg chamfer loss: 0.045956, avg density loss: 2.463687, avg pts num loss: 258.554927, avg latent xyzs loss: 0.003749, avg normal loss: 0.000000, avg bpp loss: 0.021991, avg aux loss: 2593.599728
# val epoch: 8/100, val bpp: 20.422160, val chamfer loss: 0.012683, val normal loss: 0.000000
# train epoch: 9/100, iters: 10/74, loss: 554.334258, avg chamfer loss: 0.043433, avg density loss: 2.479870, avg pts num loss: 551.785840, avg latent xyzs loss: 0.003509, avg normal loss: 0.000000, avg bpp loss: 0.021596, avg aux loss: 2400.923169
# train epoch: 9/100, iters: 20/74, loss: 403.511556, avg chamfer loss: 0.043971, avg density loss: 2.481261, avg pts num loss: 400.961353, avg latent xyzs loss: 0.003444, avg normal loss: 0.000000, avg bpp loss: 0.021524, avg aux loss: 2380.208057
# train epoch: 9/100, iters: 30/74, loss: 311.957934, avg chamfer loss: 0.043832, avg density loss: 2.469069, avg pts num loss: 309.420150, avg latent xyzs loss: 0.003421, avg normal loss: 0.000000, avg bpp loss: 0.021460, avg aux loss: 2360.104915
# train epoch: 9/100, iters: 40/74, loss: 297.521585, avg chamfer loss: 0.044005, avg density loss: 2.465863, avg pts num loss: 294.986890, avg latent xyzs loss: 0.003406, avg normal loss: 0.000000, avg bpp loss: 0.021420, avg aux loss: 2340.246472
# train epoch: 9/100, iters: 50/74, loss: 290.131277, avg chamfer loss: 0.043599, avg density loss: 2.462532, avg pts num loss: 287.600352, avg latent xyzs loss: 0.003381, avg normal loss: 0.000000, avg bpp loss: 0.021411, avg aux loss: 2320.013584
# train epoch: 9/100, iters: 60/74, loss: 262.196477, avg chamfer loss: 0.043547, avg density loss: 2.461665, avg pts num loss: 259.666528, avg latent xyzs loss: 0.003342, avg normal loss: 0.000000, avg bpp loss: 0.021393, avg aux loss: 2300.435156
# train epoch: 9/100, iters: 70/74, loss: 252.509385, avg chamfer loss: 0.043383, avg density loss: 2.461066, avg pts num loss: 249.980225, avg latent xyzs loss: 0.003321, avg normal loss: 0.000000, avg bpp loss: 0.021389, avg aux loss: 2281.382467
# train epoch: 9/100, time: 5 mins 20.8 secs, loss: 246.789638, avg chamfer loss: 0.043421, avg density loss: 2.461545, avg pts num loss: 244.259975, avg latent xyzs loss: 0.003308, avg normal loss: 0.000000, avg bpp loss: 0.021387, avg aux loss: 2273.985246
# val epoch: 9/100, val bpp: 19.964099, val chamfer loss: 0.011582, val normal loss: 0.000000
# train epoch: 10/100, iters: 10/74, loss: 335.382332, avg chamfer loss: 0.040995, avg density loss: 2.465696, avg pts num loss: 332.851318, avg latent xyzs loss: 0.003096, avg normal loss: 0.000000, avg bpp loss: 0.021232, avg aux loss: 2119.642310
# train epoch: 10/100, iters: 20/74, loss: 321.084901, avg chamfer loss: 0.041482, avg density loss: 2.472604, avg pts num loss: 318.546582, avg latent xyzs loss: 0.003042, avg normal loss: 0.000000, avg bpp loss: 0.021195, avg aux loss: 2101.937122
# train epoch: 10/100, iters: 30/74, loss: 299.062733, avg chamfer loss: 0.041779, avg density loss: 2.469353, avg pts num loss: 296.527376, avg latent xyzs loss: 0.003032, avg normal loss: 0.000000, avg bpp loss: 0.021194, avg aux loss: 2085.247278
# train epoch: 10/100, iters: 40/74, loss: 279.025046, avg chamfer loss: 0.041476, avg density loss: 2.466086, avg pts num loss: 276.493298, avg latent xyzs loss: 0.003012, avg normal loss: 0.000000, avg bpp loss: 0.021176, avg aux loss: 2069.487445
# train epoch: 10/100, iters: 50/74, loss: 267.375288, avg chamfer loss: 0.041251, avg density loss: 2.465001, avg pts num loss: 264.844844, avg latent xyzs loss: 0.002992, avg normal loss: 0.000000, avg bpp loss: 0.021203, avg aux loss: 2053.885232
# train epoch: 10/100, iters: 60/74, loss: 264.921775, avg chamfer loss: 0.041215, avg density loss: 2.463258, avg pts num loss: 262.393091, avg latent xyzs loss: 0.002986, avg normal loss: 0.000000, avg bpp loss: 0.021226, avg aux loss: 2038.878847
# train epoch: 10/100, iters: 70/74, loss: 263.892849, avg chamfer loss: 0.041172, avg density loss: 2.460540, avg pts num loss: 261.366950, avg latent xyzs loss: 0.002962, avg normal loss: 0.000000, avg bpp loss: 0.021225, avg aux loss: 2025.029630
# train epoch: 10/100, time: 5 mins 55.2 secs, loss: 260.265304, avg chamfer loss: 0.040873, avg density loss: 2.461817, avg pts num loss: 257.738395, avg latent xyzs loss: 0.002957, avg normal loss: 0.000000, avg bpp loss: 0.021262, avg aux loss: 2019.469167
# val epoch: 10/100, val bpp: 19.887205, val chamfer loss: 0.010800, val normal loss: 0.000000
# train epoch: 11/100, iters: 10/74, loss: 389.078397, avg chamfer loss: 0.039160, avg density loss: 2.452400, avg pts num loss: 386.562695, avg latent xyzs loss: 0.002784, avg normal loss: 0.000000, avg bpp loss: 0.021356, avg aux loss: 1903.781934
# train epoch: 11/100, iters: 20/74, loss: 458.621297, avg chamfer loss: 0.039413, avg density loss: 2.446188, avg pts num loss: 456.111548, avg latent xyzs loss: 0.002768, avg normal loss: 0.000000, avg bpp loss: 0.021382, avg aux loss: 1892.056122
# train epoch: 11/100, iters: 30/74, loss: 477.910243, avg chamfer loss: 0.039319, avg density loss: 2.454846, avg pts num loss: 475.391911, avg latent xyzs loss: 0.002726, avg normal loss: 0.000000, avg bpp loss: 0.021446, avg aux loss: 1878.919019
# train epoch: 11/100, iters: 40/74, loss: 444.039058, avg chamfer loss: 0.039580, avg density loss: 2.460187, avg pts num loss: 441.515076, avg latent xyzs loss: 0.002726, avg normal loss: 0.000000, avg bpp loss: 0.021493, avg aux loss: 1867.858978
# train epoch: 11/100, iters: 50/74, loss: 397.133468, avg chamfer loss: 0.039191, avg density loss: 2.463776, avg pts num loss: 394.606309, avg latent xyzs loss: 0.002714, avg normal loss: 0.000000, avg bpp loss: 0.021481, avg aux loss: 1857.253105
# train epoch: 11/100, iters: 60/74, loss: 375.628903, avg chamfer loss: 0.039089, avg density loss: 2.465851, avg pts num loss: 373.099788, avg latent xyzs loss: 0.002698, avg normal loss: 0.000000, avg bpp loss: 0.021479, avg aux loss: 1847.356993
# train epoch: 11/100, iters: 70/74, loss: 353.778121, avg chamfer loss: 0.039198, avg density loss: 2.465678, avg pts num loss: 351.249065, avg latent xyzs loss: 0.002684, avg normal loss: 0.000000, avg bpp loss: 0.021497, avg aux loss: 1837.349704
# train epoch: 11/100, time: 6 mins 29.7 secs, loss: 347.449576, avg chamfer loss: 0.039068, avg density loss: 2.467349, avg pts num loss: 344.919001, avg latent xyzs loss: 0.002667, avg normal loss: 0.000000, avg bpp loss: 0.021495, avg aux loss: 1833.303247
# val epoch: 11/100, val bpp: 20.267297, val chamfer loss: 0.010215, val normal loss: 0.000000
# train epoch: 12/100, iters: 10/74, loss: 97.991689, avg chamfer loss: 0.038889, avg density loss: 2.444609, avg pts num loss: 95.484033, avg latent xyzs loss: 0.002558, avg normal loss: 0.000000, avg bpp loss: 0.021600, avg aux loss: 1752.216272
# train epoch: 12/100, iters: 20/74, loss: 118.533236, avg chamfer loss: 0.038455, avg density loss: 2.454212, avg pts num loss: 116.016431, avg latent xyzs loss: 0.002532, avg normal loss: 0.000000, avg bpp loss: 0.021605, avg aux loss: 1743.020477
# train epoch: 12/100, iters: 30/74, loss: 126.982261, avg chamfer loss: 0.037868, avg density loss: 2.457592, avg pts num loss: 124.462663, avg latent xyzs loss: 0.002519, avg normal loss: 0.000000, avg bpp loss: 0.021617, avg aux loss: 1732.820426
# train epoch: 12/100, iters: 40/74, loss: 130.245488, avg chamfer loss: 0.037882, avg density loss: 2.455072, avg pts num loss: 127.728406, avg latent xyzs loss: 0.002500, avg normal loss: 0.000000, avg bpp loss: 0.021627, avg aux loss: 1723.322672
# train epoch: 12/100, iters: 50/74, loss: 143.504903, avg chamfer loss: 0.037483, avg density loss: 2.460900, avg pts num loss: 140.982422, avg latent xyzs loss: 0.002479, avg normal loss: 0.000000, avg bpp loss: 0.021619, avg aux loss: 1715.520095
# train epoch: 12/100, iters: 60/74, loss: 142.124699, avg chamfer loss: 0.037186, avg density loss: 2.462037, avg pts num loss: 139.601392, avg latent xyzs loss: 0.002457, avg normal loss: 0.000000, avg bpp loss: 0.021627, avg aux loss: 1707.555941
# train epoch: 12/100, iters: 70/74, loss: 141.661650, avg chamfer loss: 0.037400, avg density loss: 2.463515, avg pts num loss: 139.136677, avg latent xyzs loss: 0.002434, avg normal loss: 0.000000, avg bpp loss: 0.021622, avg aux loss: 1699.896218
# train epoch: 12/100, time: 7 mins 3.8 secs, loss: 139.894308, avg chamfer loss: 0.037470, avg density loss: 2.464725, avg pts num loss: 137.368007, avg latent xyzs loss: 0.002461, avg normal loss: 0.000000, avg bpp loss: 0.021644, avg aux loss: 1696.875241
# val epoch: 12/100, val bpp: 20.183848, val chamfer loss: 0.010112, val normal loss: 0.000000
# train epoch: 13/100, iters: 10/74, loss: 202.551191, avg chamfer loss: 0.038422, avg density loss: 2.464141, avg pts num loss: 200.024365, avg latent xyzs loss: 0.002521, avg normal loss: 0.000000, avg bpp loss: 0.021745, avg aux loss: 1635.917651
# train epoch: 13/100, iters: 20/74, loss: 272.566798, avg chamfer loss: 0.037692, avg density loss: 2.462680, avg pts num loss: 270.042212, avg latent xyzs loss: 0.002443, avg normal loss: 0.000000, avg bpp loss: 0.021774, avg aux loss: 1630.263562
# train epoch: 13/100, iters: 30/74, loss: 289.261186, avg chamfer loss: 0.037210, avg density loss: 2.463236, avg pts num loss: 286.736572, avg latent xyzs loss: 0.002405, avg normal loss: 0.000000, avg bpp loss: 0.021765, avg aux loss: 1625.065222
# train epoch: 13/100, iters: 40/74, loss: 308.205992, avg chamfer loss: 0.037195, avg density loss: 2.462820, avg pts num loss: 305.681836, avg latent xyzs loss: 0.002372, avg normal loss: 0.000000, avg bpp loss: 0.021771, avg aux loss: 1620.955447
# train epoch: 13/100, iters: 50/74, loss: 299.864672, avg chamfer loss: 0.036945, avg density loss: 2.459483, avg pts num loss: 297.344092, avg latent xyzs loss: 0.002356, avg normal loss: 0.000000, avg bpp loss: 0.021799, avg aux loss: 1616.674805
# train epoch: 13/100, iters: 60/74, loss: 288.781619, avg chamfer loss: 0.036763, avg density loss: 2.462024, avg pts num loss: 286.258700, avg latent xyzs loss: 0.002334, avg normal loss: 0.000000, avg bpp loss: 0.021800, avg aux loss: 1613.402470
# train epoch: 13/100, iters: 70/74, loss: 276.463757, avg chamfer loss: 0.036623, avg density loss: 2.464372, avg pts num loss: 273.938623, avg latent xyzs loss: 0.002320, avg normal loss: 0.000000, avg bpp loss: 0.021819, avg aux loss: 1610.153537
# train epoch: 13/100, time: 7 mins 38.1 secs, loss: 274.141726, avg chamfer loss: 0.036539, avg density loss: 2.462285, avg pts num loss: 271.618747, avg latent xyzs loss: 0.002321, avg normal loss: 0.000000, avg bpp loss: 0.021834, avg aux loss: 1609.089080
# val epoch: 13/100, val bpp: 20.465851, val chamfer loss: 0.009364, val normal loss: 0.000000
# train epoch: 14/100, iters: 10/74, loss: 220.463763, avg chamfer loss: 0.036625, avg density loss: 2.467884, avg pts num loss: 217.935010, avg latent xyzs loss: 0.002230, avg normal loss: 0.000000, avg bpp loss: 0.022014, avg aux loss: 1594.513989
# train epoch: 14/100, iters: 20/74, loss: 211.390255, avg chamfer loss: 0.036260, avg density loss: 2.472897, avg pts num loss: 208.856885, avg latent xyzs loss: 0.002201, avg normal loss: 0.000000, avg bpp loss: 0.022011, avg aux loss: 1592.326746
# train epoch: 14/100, iters: 30/74, loss: 206.083057, avg chamfer loss: 0.035833, avg density loss: 2.470669, avg pts num loss: 203.552360, avg latent xyzs loss: 0.002176, avg normal loss: 0.000000, avg bpp loss: 0.022019, avg aux loss: 1590.791821
# train epoch: 14/100, iters: 40/74, loss: 202.053487, avg chamfer loss: 0.035946, avg density loss: 2.464328, avg pts num loss: 199.529028, avg latent xyzs loss: 0.002163, avg normal loss: 0.000000, avg bpp loss: 0.022021, avg aux loss: 1588.522458
# train epoch: 14/100, iters: 50/74, loss: 203.519972, avg chamfer loss: 0.035636, avg density loss: 2.463690, avg pts num loss: 200.996465, avg latent xyzs loss: 0.002152, avg normal loss: 0.000000, avg bpp loss: 0.022028, avg aux loss: 1586.494534
# train epoch: 14/100, iters: 60/74, loss: 200.807283, avg chamfer loss: 0.035497, avg density loss: 2.461762, avg pts num loss: 198.285848, avg latent xyzs loss: 0.002148, avg normal loss: 0.000000, avg bpp loss: 0.022028, avg aux loss: 1585.208580
# train epoch: 14/100, iters: 70/74, loss: 215.977315, avg chamfer loss: 0.035416, avg density loss: 2.459083, avg pts num loss: 213.458643, avg latent xyzs loss: 0.002133, avg normal loss: 0.000000, avg bpp loss: 0.022040, avg aux loss: 1583.490398
# train epoch: 14/100, time: 8 mins 12.7 secs, loss: 218.152708, avg chamfer loss: 0.035337, avg density loss: 2.458797, avg pts num loss: 215.634372, avg latent xyzs loss: 0.002124, avg normal loss: 0.000000, avg bpp loss: 0.022077, avg aux loss: 1582.857038
# val epoch: 14/100, val bpp: 20.877111, val chamfer loss: 0.008610, val normal loss: 0.000000
# train epoch: 15/100, iters: 10/74, loss: 267.508351, avg chamfer loss: 0.033438, avg density loss: 2.439108, avg pts num loss: 265.011426, avg latent xyzs loss: 0.002062, avg normal loss: 0.000000, avg bpp loss: 0.022325, avg aux loss: 1576.476648
# train epoch: 15/100, iters: 20/74, loss: 236.906127, avg chamfer loss: 0.033358, avg density loss: 2.459565, avg pts num loss: 234.388867, avg latent xyzs loss: 0.002043, avg normal loss: 0.000000, avg bpp loss: 0.022301, avg aux loss: 1578.814758
# train epoch: 15/100, iters: 30/74, loss: 201.781126, avg chamfer loss: 0.033856, avg density loss: 2.453905, avg pts num loss: 199.269108, avg latent xyzs loss: 0.002030, avg normal loss: 0.000000, avg bpp loss: 0.022231, avg aux loss: 1580.805359
# train epoch: 15/100, iters: 40/74, loss: 182.868671, avg chamfer loss: 0.034057, avg density loss: 2.458924, avg pts num loss: 180.351465, avg latent xyzs loss: 0.002016, avg normal loss: 0.000000, avg bpp loss: 0.022212, avg aux loss: 1580.392831
# train epoch: 15/100, iters: 50/74, loss: 175.695535, avg chamfer loss: 0.033944, avg density loss: 2.460421, avg pts num loss: 173.176963, avg latent xyzs loss: 0.001996, avg normal loss: 0.000000, avg bpp loss: 0.022212, avg aux loss: 1579.880063
# train epoch: 15/100, iters: 60/74, loss: 189.172973, avg chamfer loss: 0.033927, avg density loss: 2.460002, avg pts num loss: 186.654850, avg latent xyzs loss: 0.001979, avg normal loss: 0.000000, avg bpp loss: 0.022215, avg aux loss: 1579.219240
# train epoch: 15/100, iters: 70/74, loss: 210.553579, avg chamfer loss: 0.034033, avg density loss: 2.458556, avg pts num loss: 208.036802, avg latent xyzs loss: 0.001966, avg normal loss: 0.000000, avg bpp loss: 0.022222, avg aux loss: 1578.660420
# train epoch: 15/100, time: 8 mins 46.8 secs, loss: 208.778387, avg chamfer loss: 0.034074, avg density loss: 2.456983, avg pts num loss: 206.263146, avg latent xyzs loss: 0.001963, avg normal loss: 0.000000, avg bpp loss: 0.022222, avg aux loss: 1578.605035
# val epoch: 15/100, val bpp: 20.877775, val chamfer loss: 0.008314, val normal loss: 0.000000
# train epoch: 16/100, iters: 10/74, loss: 257.125247, avg chamfer loss: 0.033506, avg density loss: 2.455885, avg pts num loss: 254.611621, avg latent xyzs loss: 0.001889, avg normal loss: 0.000000, avg bpp loss: 0.022348, avg aux loss: 1573.323218
# train epoch: 16/100, iters: 20/74, loss: 254.818023, avg chamfer loss: 0.033491, avg density loss: 2.455710, avg pts num loss: 252.304614, avg latent xyzs loss: 0.001904, avg normal loss: 0.000000, avg bpp loss: 0.022303, avg aux loss: 1572.389948
# train epoch: 16/100, iters: 30/74, loss: 254.896377, avg chamfer loss: 0.033518, avg density loss: 2.458041, avg pts num loss: 252.380632, avg latent xyzs loss: 0.001880, avg normal loss: 0.000000, avg bpp loss: 0.022305, avg aux loss: 1572.013826
# train epoch: 16/100, iters: 40/74, loss: 271.404358, avg chamfer loss: 0.033494, avg density loss: 2.456143, avg pts num loss: 268.890540, avg latent xyzs loss: 0.001865, avg normal loss: 0.000000, avg bpp loss: 0.022317, avg aux loss: 1571.178110
# train epoch: 16/100, iters: 50/74, loss: 252.826475, avg chamfer loss: 0.033343, avg density loss: 2.454680, avg pts num loss: 250.314238, avg latent xyzs loss: 0.001870, avg normal loss: 0.000000, avg bpp loss: 0.022344, avg aux loss: 1570.504778
# train epoch: 16/100, iters: 60/74, loss: 248.886680, avg chamfer loss: 0.033403, avg density loss: 2.454485, avg pts num loss: 246.374577, avg latent xyzs loss: 0.001859, avg normal loss: 0.000000, avg bpp loss: 0.022358, avg aux loss: 1570.282513
# train epoch: 16/100, iters: 70/74, loss: 251.907762, avg chamfer loss: 0.033333, avg density loss: 2.457061, avg pts num loss: 249.393136, avg latent xyzs loss: 0.001852, avg normal loss: 0.000000, avg bpp loss: 0.022381, avg aux loss: 1570.312826
# train epoch: 16/100, time: 9 mins 21.3 secs, loss: 244.676034, avg chamfer loss: 0.033270, avg density loss: 2.456708, avg pts num loss: 242.161835, avg latent xyzs loss: 0.001850, avg normal loss: 0.000000, avg bpp loss: 0.022372, avg aux loss: 1570.141110
# val epoch: 16/100, val bpp: 21.043851, val chamfer loss: 0.008227, val normal loss: 0.000000
# train epoch: 17/100, iters: 10/74, loss: 257.343719, avg chamfer loss: 0.033536, avg density loss: 2.433920, avg pts num loss: 254.851855, avg latent xyzs loss: 0.001822, avg normal loss: 0.000000, avg bpp loss: 0.022583, avg aux loss: 1566.158533
# train epoch: 17/100, iters: 20/74, loss: 263.539604, avg chamfer loss: 0.032862, avg density loss: 2.451817, avg pts num loss: 261.030615, avg latent xyzs loss: 0.001807, avg normal loss: 0.000000, avg bpp loss: 0.022503, avg aux loss: 1569.262189
# ...
# train epoch: 93/100, iters: 40/74, loss: 36.980189, avg chamfer loss: 0.024448, avg density loss: 2.444414, avg pts num loss: 34.492529, avg latent xyzs loss: 0.000776, avg normal loss: 0.000000, avg bpp loss: 0.018021, avg aux loss: 1478.649887
# train epoch: 93/100, iters: 50/74, loss: 35.062720, avg chamfer loss: 0.024421, avg density loss: 2.443059, avg pts num loss: 32.576445, avg latent xyzs loss: 0.000777, avg normal loss: 0.000000, avg bpp loss: 0.018018, avg aux loss: 1478.178865
# train epoch: 93/100, iters: 60/74, loss: 35.801373, avg chamfer loss: 0.024348, avg density loss: 2.446357, avg pts num loss: 33.311865, avg latent xyzs loss: 0.000779, avg normal loss: 0.000000, avg bpp loss: 0.018024, avg aux loss: 1477.775865
# train epoch: 93/100, iters: 70/74, loss: 36.113261, avg chamfer loss: 0.024379, avg density loss: 2.446703, avg pts num loss: 33.623368, avg latent xyzs loss: 0.000781, avg normal loss: 0.000000, avg bpp loss: 0.018031, avg aux loss: 1477.498431
# train epoch: 93/100, time: 54 mins 9.3 secs, loss: 37.298859, avg chamfer loss: 0.024239, avg density loss: 2.445130, avg pts num loss: 34.810684, avg latent xyzs loss: 0.000780, avg normal loss: 0.000000, avg bpp loss: 0.018025, avg aux loss: 1477.408078
# val epoch: 93/100, val bpp: 15.051625, val chamfer loss: 0.006943, val normal loss: 0.000000
# train epoch: 94/100, iters: 10/74, loss: 56.767929, avg chamfer loss: 0.023933, avg density loss: 2.438159, avg pts num loss: 54.287109, avg latent xyzs loss: 0.000759, avg normal loss: 0.000000, avg bpp loss: 0.017970, avg aux loss: 1475.394495
# train epoch: 94/100, iters: 20/74, loss: 50.727182, avg chamfer loss: 0.024203, avg density loss: 2.444136, avg pts num loss: 48.240112, avg latent xyzs loss: 0.000775, avg normal loss: 0.000000, avg bpp loss: 0.017956, avg aux loss: 1474.888904
# train epoch: 94/100, iters: 30/74, loss: 49.551090, avg chamfer loss: 0.024371, avg density loss: 2.440286, avg pts num loss: 47.067676, avg latent xyzs loss: 0.000779, avg normal loss: 0.000000, avg bpp loss: 0.017979, avg aux loss: 1474.348844
# train epoch: 94/100, iters: 40/74, loss: 46.050515, avg chamfer loss: 0.024407, avg density loss: 2.442956, avg pts num loss: 43.564380, avg latent xyzs loss: 0.000780, avg normal loss: 0.000000, avg bpp loss: 0.017993, avg aux loss: 1473.880707
# train epoch: 94/100, iters: 50/74, loss: 43.273890, avg chamfer loss: 0.024447, avg density loss: 2.441222, avg pts num loss: 40.789463, avg latent xyzs loss: 0.000775, avg normal loss: 0.000000, avg bpp loss: 0.017983, avg aux loss: 1473.512053
# train epoch: 94/100, iters: 60/74, loss: 43.362693, avg chamfer loss: 0.024300, avg density loss: 2.441735, avg pts num loss: 40.877897, avg latent xyzs loss: 0.000779, avg normal loss: 0.000000, avg bpp loss: 0.017983, avg aux loss: 1473.155318
# train epoch: 94/100, iters: 70/74, loss: 43.501043, avg chamfer loss: 0.024333, avg density loss: 2.443393, avg pts num loss: 41.014551, avg latent xyzs loss: 0.000778, avg normal loss: 0.000000, avg bpp loss: 0.017988, avg aux loss: 1472.858508
# train epoch: 94/100, time: 54 mins 44.0 secs, loss: 42.451438, avg chamfer loss: 0.024388, avg density loss: 2.443462, avg pts num loss: 39.964823, avg latent xyzs loss: 0.000777, avg normal loss: 0.000000, avg bpp loss: 0.017988, avg aux loss: 1472.749436
# val epoch: 94/100, val bpp: 15.045071, val chamfer loss: 0.006954, val normal loss: 0.000000
# train epoch: 95/100, iters: 10/74, loss: 42.791601, avg chamfer loss: 0.023765, avg density loss: 2.431366, avg pts num loss: 40.317725, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017973, avg aux loss: 1470.776086
# train epoch: 95/100, iters: 20/74, loss: 41.645780, avg chamfer loss: 0.024384, avg density loss: 2.439236, avg pts num loss: 39.163477, avg latent xyzs loss: 0.000768, avg normal loss: 0.000000, avg bpp loss: 0.017915, avg aux loss: 1470.452039
# train epoch: 95/100, iters: 30/74, loss: 40.458184, avg chamfer loss: 0.024395, avg density loss: 2.441970, avg pts num loss: 37.973112, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017938, avg aux loss: 1469.954171
# train epoch: 95/100, iters: 40/74, loss: 43.061389, avg chamfer loss: 0.024421, avg density loss: 2.445047, avg pts num loss: 40.573206, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017947, avg aux loss: 1469.505038
# train epoch: 95/100, iters: 50/74, loss: 43.599355, avg chamfer loss: 0.024593, avg density loss: 2.442200, avg pts num loss: 41.113838, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017953, avg aux loss: 1469.170562
# train epoch: 95/100, iters: 60/74, loss: 46.601858, avg chamfer loss: 0.024506, avg density loss: 2.443195, avg pts num loss: 44.115430, avg latent xyzs loss: 0.000775, avg normal loss: 0.000000, avg bpp loss: 0.017952, avg aux loss: 1468.967452
# train epoch: 95/100, iters: 70/74, loss: 49.601866, avg chamfer loss: 0.024362, avg density loss: 2.444038, avg pts num loss: 47.114739, avg latent xyzs loss: 0.000774, avg normal loss: 0.000000, avg bpp loss: 0.017954, avg aux loss: 1468.830071
# train epoch: 95/100, time: 55 mins 18.1 secs, loss: 48.583336, avg chamfer loss: 0.024376, avg density loss: 2.442893, avg pts num loss: 46.097347, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017947, avg aux loss: 1468.772106
# val epoch: 95/100, val bpp: 14.955362, val chamfer loss: 0.006805, val normal loss: 0.000000
# train epoch: 96/100, iters: 10/74, loss: 66.015770, avg chamfer loss: 0.024148, avg density loss: 2.445604, avg pts num loss: 63.527295, avg latent xyzs loss: 0.000792, avg normal loss: 0.000000, avg bpp loss: 0.017931, avg aux loss: 1467.244751
# train epoch: 96/100, iters: 20/74, loss: 44.704612, avg chamfer loss: 0.024549, avg density loss: 2.436227, avg pts num loss: 42.225146, avg latent xyzs loss: 0.000783, avg normal loss: 0.000000, avg bpp loss: 0.017907, avg aux loss: 1466.924994
# train epoch: 96/100, iters: 30/74, loss: 42.946523, avg chamfer loss: 0.024149, avg density loss: 2.445468, avg pts num loss: 40.458219, avg latent xyzs loss: 0.000779, avg normal loss: 0.000000, avg bpp loss: 0.017907, avg aux loss: 1466.512830
# train epoch: 96/100, iters: 40/74, loss: 39.420642, avg chamfer loss: 0.023899, avg density loss: 2.444162, avg pts num loss: 36.933899, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017910, avg aux loss: 1466.012311
# train epoch: 96/100, iters: 50/74, loss: 36.842691, avg chamfer loss: 0.024231, avg density loss: 2.445036, avg pts num loss: 34.354746, avg latent xyzs loss: 0.000770, avg normal loss: 0.000000, avg bpp loss: 0.017907, avg aux loss: 1465.592932
# train epoch: 96/100, iters: 60/74, loss: 35.414826, avg chamfer loss: 0.024266, avg density loss: 2.446249, avg pts num loss: 32.925635, avg latent xyzs loss: 0.000771, avg normal loss: 0.000000, avg bpp loss: 0.017906, avg aux loss: 1465.274760
# train epoch: 96/100, iters: 70/74, loss: 33.537538, avg chamfer loss: 0.024393, avg density loss: 2.445610, avg pts num loss: 31.048849, avg latent xyzs loss: 0.000773, avg normal loss: 0.000000, avg bpp loss: 0.017913, avg aux loss: 1465.011787
# train epoch: 96/100, time: 55 mins 52.2 secs, loss: 32.519612, avg chamfer loss: 0.024293, avg density loss: 2.442360, avg pts num loss: 30.034262, avg latent xyzs loss: 0.000773, avg normal loss: 0.000000, avg bpp loss: 0.017922, avg aux loss: 1464.929701
# val epoch: 96/100, val bpp: 15.002402, val chamfer loss: 0.006854, val normal loss: 0.000000
# train epoch: 97/100, iters: 10/74, loss: 27.597374, avg chamfer loss: 0.024347, avg density loss: 2.465238, avg pts num loss: 25.089160, avg latent xyzs loss: 0.000762, avg normal loss: 0.000000, avg bpp loss: 0.017867, avg aux loss: 1464.266125
# train epoch: 97/100, iters: 20/74, loss: 37.183737, avg chamfer loss: 0.024111, avg density loss: 2.451284, avg pts num loss: 34.689673, avg latent xyzs loss: 0.000773, avg normal loss: 0.000000, avg bpp loss: 0.017897, avg aux loss: 1464.239954
# train epoch: 97/100, iters: 30/74, loss: 33.656719, avg chamfer loss: 0.024190, avg density loss: 2.441021, avg pts num loss: 31.172852, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017888, avg aux loss: 1464.028959
# train epoch: 97/100, iters: 40/74, loss: 31.773165, avg chamfer loss: 0.024107, avg density loss: 2.441918, avg pts num loss: 29.288477, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017894, avg aux loss: 1463.769629
# train epoch: 97/100, iters: 50/74, loss: 31.340477, avg chamfer loss: 0.024213, avg density loss: 2.443356, avg pts num loss: 28.854258, avg latent xyzs loss: 0.000765, avg normal loss: 0.000000, avg bpp loss: 0.017885, avg aux loss: 1463.509128
# train epoch: 97/100, iters: 60/74, loss: 30.750358, avg chamfer loss: 0.024251, avg density loss: 2.444320, avg pts num loss: 28.263135, avg latent xyzs loss: 0.000767, avg normal loss: 0.000000, avg bpp loss: 0.017885, avg aux loss: 1463.212606
# train epoch: 97/100, iters: 70/74, loss: 30.402353, avg chamfer loss: 0.024414, avg density loss: 2.446410, avg pts num loss: 27.912877, avg latent xyzs loss: 0.000768, avg normal loss: 0.000000, avg bpp loss: 0.017884, avg aux loss: 1462.913520
# train epoch: 97/100, time: 56 mins 26.8 secs, loss: 30.078595, avg chamfer loss: 0.024256, avg density loss: 2.444700, avg pts num loss: 27.590980, avg latent xyzs loss: 0.000770, avg normal loss: 0.000000, avg bpp loss: 0.017888, avg aux loss: 1462.785194
# val epoch: 97/100, val bpp: 14.910541, val chamfer loss: 0.006944, val normal loss: 0.000000
# train epoch: 98/100, iters: 10/74, loss: 40.324092, avg chamfer loss: 0.024761, avg density loss: 2.425893, avg pts num loss: 37.854834, avg latent xyzs loss: 0.000739, avg normal loss: 0.000000, avg bpp loss: 0.017864, avg aux loss: 1460.375232
# train epoch: 98/100, iters: 20/74, loss: 37.631954, avg chamfer loss: 0.024120, avg density loss: 2.438878, avg pts num loss: 35.150317, avg latent xyzs loss: 0.000767, avg normal loss: 0.000000, avg bpp loss: 0.017871, avg aux loss: 1460.158960
# train epoch: 98/100, iters: 30/74, loss: 32.390301, avg chamfer loss: 0.024268, avg density loss: 2.442042, avg pts num loss: 29.905355, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017866, avg aux loss: 1459.991536
# train epoch: 98/100, iters: 40/74, loss: 30.127730, avg chamfer loss: 0.024140, avg density loss: 2.441232, avg pts num loss: 27.643713, avg latent xyzs loss: 0.000766, avg normal loss: 0.000000, avg bpp loss: 0.017877, avg aux loss: 1459.787595
# train epoch: 98/100, iters: 50/74, loss: 27.941332, avg chamfer loss: 0.024283, avg density loss: 2.444006, avg pts num loss: 25.454414, avg latent xyzs loss: 0.000767, avg normal loss: 0.000000, avg bpp loss: 0.017861, avg aux loss: 1459.534509
# train epoch: 98/100, iters: 60/74, loss: 27.361257, avg chamfer loss: 0.024257, avg density loss: 2.446789, avg pts num loss: 24.871582, avg latent xyzs loss: 0.000773, avg normal loss: 0.000000, avg bpp loss: 0.017855, avg aux loss: 1459.258002
# train epoch: 98/100, iters: 70/74, loss: 28.289581, avg chamfer loss: 0.024413, avg density loss: 2.444623, avg pts num loss: 25.801918, avg latent xyzs loss: 0.000773, avg normal loss: 0.000000, avg bpp loss: 0.017853, avg aux loss: 1459.053292
# train epoch: 98/100, time: 57 mins 1.5 secs, loss: 29.236797, avg chamfer loss: 0.024329, avg density loss: 2.445241, avg pts num loss: 26.748601, avg latent xyzs loss: 0.000775, avg normal loss: 0.000000, avg bpp loss: 0.017851, avg aux loss: 1458.982245
# val epoch: 98/100, val bpp: 14.906563, val chamfer loss: 0.006934, val normal loss: 0.000000
# train epoch: 99/100, iters: 10/74, loss: 23.558467, avg chamfer loss: 0.023440, avg density loss: 2.415136, avg pts num loss: 21.101318, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017804, avg aux loss: 1458.114868
# train epoch: 99/100, iters: 20/74, loss: 27.019520, avg chamfer loss: 0.024211, avg density loss: 2.424643, avg pts num loss: 24.552100, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017798, avg aux loss: 1457.927692
# train epoch: 99/100, iters: 30/74, loss: 28.996289, avg chamfer loss: 0.024187, avg density loss: 2.435856, avg pts num loss: 26.517676, avg latent xyzs loss: 0.000771, avg normal loss: 0.000000, avg bpp loss: 0.017799, avg aux loss: 1457.615951
# train epoch: 99/100, iters: 40/74, loss: 29.726142, avg chamfer loss: 0.024032, avg density loss: 2.433996, avg pts num loss: 27.249536, avg latent xyzs loss: 0.000771, avg normal loss: 0.000000, avg bpp loss: 0.017807, avg aux loss: 1457.318689
# train epoch: 99/100, iters: 50/74, loss: 31.321829, avg chamfer loss: 0.024207, avg density loss: 2.436815, avg pts num loss: 28.842217, avg latent xyzs loss: 0.000770, avg normal loss: 0.000000, avg bpp loss: 0.017821, avg aux loss: 1457.141311
# train epoch: 99/100, iters: 60/74, loss: 32.465491, avg chamfer loss: 0.024294, avg density loss: 2.436607, avg pts num loss: 29.986003, avg latent xyzs loss: 0.000771, avg normal loss: 0.000000, avg bpp loss: 0.017815, avg aux loss: 1457.052639
# train epoch: 99/100, iters: 70/74, loss: 35.405297, avg chamfer loss: 0.024312, avg density loss: 2.443385, avg pts num loss: 32.919015, avg latent xyzs loss: 0.000771, avg normal loss: 0.000000, avg bpp loss: 0.017814, avg aux loss: 1456.919706
# train epoch: 99/100, time: 57 mins 35.7 secs, loss: 35.583969, avg chamfer loss: 0.024558, avg density loss: 2.442581, avg pts num loss: 33.098245, avg latent xyzs loss: 0.000769, avg normal loss: 0.000000, avg bpp loss: 0.017815, avg aux loss: 1456.846579
# val epoch: 99/100, val bpp: 14.825608, val chamfer loss: 0.006987, val normal loss: 0.000000
# train epoch: 100/100, iters: 10/74, loss: 23.863069, avg chamfer loss: 0.024530, avg density loss: 2.437787, avg pts num loss: 21.382227, avg latent xyzs loss: 0.000778, avg normal loss: 0.000000, avg bpp loss: 0.017747, avg aux loss: 1455.045410
# train epoch: 100/100, iters: 20/74, loss: 22.841199, avg chamfer loss: 0.024660, avg density loss: 2.444416, avg pts num loss: 20.353564, avg latent xyzs loss: 0.000782, avg normal loss: 0.000000, avg bpp loss: 0.017777, avg aux loss: 1454.673059
# train epoch: 100/100, iters: 30/74, loss: 32.050396, avg chamfer loss: 0.024729, avg density loss: 2.444172, avg pts num loss: 29.562956, avg latent xyzs loss: 0.000774, avg normal loss: 0.000000, avg bpp loss: 0.017766, avg aux loss: 1454.512427
# train epoch: 100/100, iters: 40/74, loss: 34.089109, avg chamfer loss: 0.024564, avg density loss: 2.446396, avg pts num loss: 31.599597, avg latent xyzs loss: 0.000779, avg normal loss: 0.000000, avg bpp loss: 0.017774, avg aux loss: 1454.394412
# train epoch: 100/100, iters: 50/74, loss: 34.809025, avg chamfer loss: 0.024330, avg density loss: 2.445821, avg pts num loss: 32.320332, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017771, avg aux loss: 1454.281692
# train epoch: 100/100, iters: 60/74, loss: 33.583360, avg chamfer loss: 0.024400, avg density loss: 2.443989, avg pts num loss: 31.096427, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017772, avg aux loss: 1454.198545
# train epoch: 100/100, iters: 70/74, loss: 34.522898, avg chamfer loss: 0.024258, avg density loss: 2.442808, avg pts num loss: 32.037284, avg latent xyzs loss: 0.000772, avg normal loss: 0.000000, avg bpp loss: 0.017776, avg aux loss: 1454.123811
# train epoch: 100/100, time: 58 mins 9.9 secs, loss: 34.274469, avg chamfer loss: 0.024274, avg density loss: 2.443147, avg pts num loss: 31.788498, avg latent xyzs loss: 0.000770, avg normal loss: 0.000000, avg bpp loss: 0.017780, avg aux loss: 1454.078384
# val epoch: 100/100, val bpp: 14.786075, val chamfer loss: 0.007003, val normal loss: 0.000000
